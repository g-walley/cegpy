# %%
import logging
from src.cegpy.trees.staged import StagedTree
from src.cegpy.trees.event import EventTree
import pandas as pd
import numpy as np
import networkx as nx

# %%
df = pd.read_excel("/home/pstrong/Documents/cegpy/cegpy/data/Falls_Data.xlsx")

# %%
falls_et = EventTree(dataframe=df)
falls_st = StagedTree(dataframe=df)

# %%
a=falls_et
falls_et.create_figure("et_fig_path")
#falls_et.adj

# %%
df["extra"]=""
df
cols = list(df.columns.values)
df=df[cols[4]]#.append(cols[0:3])]
# falls_et = EventTree(dataframe=df)
# falls_st = StagedTree(dataframe=df)
# falls_et.create_figure("et_fig_path")
df
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 49995
# 49996
# 49997
# 49998
# 49999
# Name: extra, Length: 50000, dtype: object

# %%
(falls_et.leaves)[1]

# %%
falls_et.remove_nodes_from(falls_et.leaves)

# %%
falls_et

# %%
falls_et.create_figure("et_fig_path")

# %%
nx.is_isomorphic(a,falls_et)
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-10da3b4f2612> in <module>
# ----> 1 a.edges
#
# AttributeError: 'MultiAdjacencyView' object has no attribute 'edges'
